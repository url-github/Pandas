# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %% [markdown]
# ![2021-08-22 12_42_20-Data Science_ Analiza danych w Python i PANDAS _ Udemy.png](data:image/png;base64,...)

# %%
bar = pd.read_csv('/content/weather_barcelona.csv', index_col='Date')
rom = pd.read_csv('/content/weather_rome.csv', index_col='Date')
ams = pd.read_csv('/content/weather_amsterdam.csv', index_col='Date')

# %%
temp_max = pd.DataFrame(index = bar.index)

# %%
temp_max['Barcelona'] = bar['TempMax']
temp_max['Rome'] = rom['TempMax']
temp_max['Amsterdam'] = ams['TempMax']

temp_max.head()
# Out:
#             Barcelona  Rome  Amsterdam
# Date
# 2018-01-01         17    14          8
# 2018-01-02         19    13          9
# 2018-01-03         23    14         11
# 2018-01-04         24    16         11
# 2018-01-05         20    17          8

# %%
def GradeDay(row):
  if(row['TempMax'] >= row['AvgTempMax']):
    return 'PLUS'
  else:
    return 'MINUS'

# %%
rom['GradeDay'] = rom.apply(GradeDay, axis=1)
bar['GradeDay'] = bar.apply(GradeDay, axis=1)
ams['GradeDay'] = ams.apply(GradeDay, axis=1)

# %%
rom.head()
# Out:
#             TempMax  TempMin Rain  AvgTempMax  AvgTempMin GradeDay
# Date
# 2018-01-01       14        8   0           12           4     PLUS
# 2018-01-02       13        7   0           12           4     PLUS
# 2018-01-03       14        1   0           12           4     PLUS
# 2018-01-04       16        6   0           12           4     PLUS
# 2018-01-05       17        7   0           12           3     PLUS

# %%
rom['GradeDay'].value_counts()
# Out:
# PLUS     70
# MINUS    20
# Name: GradeDay, dtype: int64

# %%
cities3 = pd.DataFrame(index=['MINUS', 'PLUS'])

# %%
cities3['Barcelona'] = bar['GradeDay'].value_counts()

# %%
cities3['Rome'] = rom['GradeDay'].value_counts()

# %%
cities3['Amsterdam'] = ams['GradeDay'].value_counts()

# %%
cities3.head()
# Out:
#        Barcelona  Rome  Amsterdam
# MINUS         26    20         22
# PLUS          64    70         68

# %%
cities3['Barcelona'].plot(kind='pie')

# %%
cities3.plot(kind='pie', subplots=True, figsize=(15,5),colors=['b','g'])
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f52d4bc5510>,
# ...
#       dtype=object)

# %%
cities3.plot(kind='pie', subplots=True, figsize=(15,5),colors=['b','g'], labels=['colder', 'warmer'])
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f52d4ac74d0>,
# ...
#       dtype=object)

# %%
cities3.plot(kind='pie', subplots=True, figsize=(15,5),colors=['b','g'], labels=['colder', 'warmer'],
             autopct='%.0f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f52d49b1650>,
# ...
#       dtype=object)

# %%
cities3.plot(kind='pie', subplots=True, figsize=(15,5),colors=['g','r'], labels=['colder', 'warmer'],
             autopct='%.0f%%', fontsize=13)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f52d47d4e90>,
# ...
#       dtype=object)

# %%
cities3.plot(kind='pie', subplots=True, figsize=(15,5),colors=['g','r'], labels=['colder', 'warmer'],
             autopct='%.0f%%', fontsize=13, textprops=dict(color='w'))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f52d42eb210>,
# ...
#       dtype=object)

# %%
cities3.plot(kind='pie', subplots=True, figsize=(20,10),colors=['g','r'], labels=['colder', 'warmer'],
             autopct='%.0f%%', fontsize=13, textprops=dict(color='w'), layout=(2,2))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f52d3c42490>,
# ...
#       dtype=object)

# %%
cities3.plot(kind='pie', subplots=True, figsize=(15,5),colors=['g','r'], labels=['colder', 'warmer'],
             autopct='%.0f%%', fontsize=13, textprops=dict(color='w'), explode=(0.2,0))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f52d395a550>,
# ...
#       dtype=object)
