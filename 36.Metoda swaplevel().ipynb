# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ![2021-08-18 09_39_12-Window.png](data:image/png;base64,...)

# %%
incidents = pd.read_csv('/content/Canadian Railway Crossing Incidents.csv')
incidents.set_index(['Region', 'EventType'],inplace=True)
incidents.sort_index(inplace=True)
incidents.head(10)
# Out:
#                                    Public automated  ...  Farm
# Region           EventType                           ...
# Alberta          Accidents                        3  ...     0
#                  Fatalities                       0  ...     0
#                  Serious injuries                 0  ...     0
# British Columbia Accidents                        4  ...     0
#                  Fatalities                       0  ...     0
#                  Serious injuries                 3  ...     0
# Manitoba         Accidents                        1  ...     2
#                  Fatalities                       0  ...     0
#                  Serious injuries                 0  ...     1
# New Brunswick    Accidents                        0  ...     0
#
# [10 rows x 4 columns]

# %%
incidents.reset_index(inplace=True)
incidents.set_index(['EventType', 'Region'],inplace=True)
incidents.head()
# Out:
#                                    Public automated  ...  Farm
# EventType        Region                              ...
# Accidents        Alberta                          3  ...     0
# Fatalities       Alberta                          0  ...     0
# Serious injuries Alberta                          0  ...     0
# Accidents        British Columbia                 4  ...     0
# Fatalities       British Columbia                 0  ...     0
#
# [5 rows x 4 columns]

# %%
incidents.sort_index(inplace=True)
incidents.head()
# Out:
#                             Public automated  Public passive  Private  Farm
# EventType Region
# Accidents Alberta                          3               7        2     0
#           British Columbia                 4               1        0     0
#           Manitoba                         1               3        0     2
#           New Brunswick                    0               0        0     0
#           Newfoundland                     0               0        0     0

# %%
incidents.swaplevel().head()
# Out:
#                             Public automated  Public passive  Private  Farm
# Region           EventType
# Alberta          Accidents                 3               7        2     0
# British Columbia Accidents                 4               1        0     0
# Manitoba         Accidents                 1               3        0     2
# New Brunswick    Accidents                 0               0        0     0
# Newfoundland     Accidents                 0               0        0     0

# %%
incidents.swaplevel().sort_index().head()
# Out:
#                                    Public automated  ...  Farm
# Region           EventType                           ...
# Alberta          Accidents                        3  ...     0
#                  Fatalities                       0  ...     0
#                  Serious injuries                 0  ...     0
# British Columbia Accidents                        4  ...     0
#                  Fatalities                       0  ...     0
#
# [5 rows x 4 columns]

# %%
incidents = incidents.swaplevel().sort_index()
incidents.head()
# Out:
#                                    Public automated  ...  Farm
# Region           EventType                           ...
# Alberta          Accidents                        3  ...     0
#                  Fatalities                       0  ...     0
#                  Serious injuries                 0  ...     0
# British Columbia Accidents                        4  ...     0
#                  Fatalities                       0  ...     0
#
# [5 rows x 4 columns]
