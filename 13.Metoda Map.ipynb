# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math

# %% [markdown]
# ![2021-08-14 18_24_39-Data Science_ Analiza danych w Python i PANDAS _ Udemy.png](data:image/png;base64,...)

# %%
# Map wykonuje czynność na 2 seriach danych

team = pd.Series(data=[5,3,5,7,8,4,6,8], index=['Piotr', 'Tadek', 'Agusia', 'Stefan', 'Henry', 'Ivan', 'Olek', 'Antek'])
team
# Out:
# Piotr     5
# Tadek     3
# Agusia    5
# Stefan    7
# Henry     8
# Ivan      4
# Olek      6
# Antek     8
# dtype: int64

# %%
notes=pd.Series(data=['C','C','B','A','A+'], index=[1,2,3,4,5])
notes
# Out:
# 1     C
# 2     C
# 3     B
# 4     A
# 5    A+
# dtype: object

# %%
team.map(notes)
# Out:
# Piotr      A+
# Tadek       B
# Agusia     A+
# Stefan    NaN
# Henry     NaN
# Ivan        A
# Olek      NaN
# Antek     NaN
# dtype: object
