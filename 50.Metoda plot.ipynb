# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %% [markdown]
# ![2021-08-22 09_49_46-Data Science_ Analiza danych w Python i PANDAS _ Udemy.png](data:image/png;base64,...)

# %%
bar = pd.read_csv('/content/weather_barcelona.csv', index_col='Date')
rome = pd.read_csv('/content/weather_rome.csv', index_col='Date')
ams = pd.read_csv('/content/weather_amsterdam.csv', index_col='Date')

# %%
bar.head()
# Out:
#             TempMax  TempMin  Rain  AvgTempMax  AvgTempMin
# Date
# 2018-01-01       17       11     0          13           7
# 2018-01-02       19        8     0          13           7
# 2018-01-03       23       11     0          13           7
# 2018-01-04       24       15     0          13           7
# 2018-01-05       20       10     0          13           7

# %%
bar.plot()

# %%
bar['TempMax'].plot()

# %%
bar.plot(y='TempMax')

# %%
bar[['TempMax', 'TempMin']].plot()

# %%
bar.plot(y=['TempMax', 'TempMin'])
