# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ![2021-08-19 16_03_22-Window.png](data:image/png;base64,...)

# %%
products = pd.read_csv('/content/WA_Sales_Products_2012-14.csv')
products.head()
# Out:
#   Retailer country Order method type  ... Quantity Gross margin
# 0    United States               Fax  ...      489     0.347548
# 1    United States               Fax  ...      252     0.474274
# 2    United States               Fax  ...      147     0.352772
# 3    United States               Fax  ...      303     0.282938
# 4    United States               Fax  ...     1415     0.291450
#
# [5 rows x 11 columns]

# %%
groups = products.groupby(by='Retailer country')
groups.mean().head()
# Out:
#                          Year       Revenue    Quantity  Gross margin
# Retailer country
# Australia         2012.859482  29822.638237  545.915689      0.451174
# Austria           2012.875971  29354.380023  544.330917      0.450913
# Belgium           2012.878976  26134.385420  484.911321      0.448410
# Brazil            2012.878954  33170.824647  595.332117      0.448023
# Canada            2012.839946  41682.874366  746.098936      0.451011

# %%
groups.sum().head()
# Out:
#                       Year       Revenue  Quantity  Gross margin
# Retailer country
# Australia          7377130  1.093000e+08   2000781   1641.822415
# Austria            7773727  1.133666e+08   2102206   1723.839177
# Belgium            7467781  9.695857e+07   1799021   1653.288385
# Brazil             6618346  1.090657e+08   1957452   1466.380765
# Canada            11922051  2.468877e+08   4419144   2662.767825

# %%
groups.count().head()
# Out:
#                   Order method type  Retailer type  ...  Quantity  Gross margin
# Retailer country                                    ...
# Australia                      3665           3665  ...      3665          3639
# Austria                        3862           3862  ...      3862          3823
# Belgium                        3710           3710  ...      3710          3687
# Brazil                         3288           3288  ...      3288          3273
# Canada                         5923           5923  ...      5923          5904
#
# [5 rows x 10 columns]

# %%
groups.min().head()
# Out:
#                  Order method type     Retailer type  ... Quantity Gross margin
# Retailer country                                      ...
# Australia                   E-mail  Department Store  ...        1    -0.389517
# Austria                Sales visit  Department Store  ...        4    -0.086616
# Belgium                        Fax  Department Store  ...        5    -1.476136
# Brazil                      E-mail  Department Store  ...        4    -2.085496
# Canada                      E-mail  Department Store  ...        1    -1.373907
#
# [5 rows x 10 columns]

# %%
groups.max().head()
# Out:
#                  Order method type    Retailer type  ... Quantity Gross margin
# Retailer country                                     ...
# Australia                      Web  Warehouse Store  ...    20031     0.770476
# Austria                        Web  Warehouse Store  ...     9662     0.770476
# Belgium                        Web  Warehouse Store  ...    13200     0.770476
# Brazil                         Web  Warehouse Store  ...    12157     0.770476
# Canada                         Web  Warehouse Store  ...    27268     0.770476
#
# [5 rows x 10 columns]

# %% [markdown]
# Wniosek z poniższego jest taki, że taki rekord nie istnieje zatem powyższe grupowanie min & max wyciąga wartości min & max dla poszczególnych kolumn

# %%
products.loc[(products['Retailer country'] == 'Australia') &
            (products['Order method type'] == 'Web') &
            (products['Retailer type'] == 'Warehouse Store') &
            (products['Product line'] == 'Personal Accessories') &
            (products['Product type'] == 'Woods')].head()
# Out:
# Empty DataFrame
# Columns: [Retailer country, Order method type, Retailer type, Product line, Product type, Product, Year, Quarter, Revenue, Quantity, Gross margin]
# Index: []

# %%
groups['Revenue'].sum().head()
# Out:
# Retailer country
# Australia    1.093000e+08
# Austria      1.133666e+08
# Belgium      9.695857e+07
# Brazil       1.090657e+08
# Canada       2.468877e+08
# Name: Revenue, dtype: float64

# %%
groups[['Revenue', 'Quantity']].mean().head()
# Out:
#                        Revenue    Quantity
# Retailer country
# Australia         29822.638237  545.915689
# Austria           29354.380023  544.330917
# Belgium           26134.385420  484.911321
# Brazil            33170.824647  595.332117
# Canada            41682.874366  746.098936
