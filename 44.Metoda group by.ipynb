# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ![2021-08-19 15_26_13-Data Science_ Analiza danych w Python i PANDAS _ Udemy.png](data:image/png;base64,...)

# %%
products = pd.read_csv('/content/WA_Sales_Products_2012-14.csv')
products.head()
# Out:
#   Retailer country Order method type  ... Quantity Gross margin
# 0    United States               Fax  ...      489     0.347548
# 1    United States               Fax  ...      252     0.474274
# 2    United States               Fax  ...      147     0.352772
# 3    United States               Fax  ...      303     0.282938
# 4    United States               Fax  ...     1415     0.291450
#
# [5 rows x 11 columns]

# %%
products.groupby(by='Retailer country')

# %%
groups = products.groupby(by='Retailer country')
type(groups)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
len(groups)
# Out:
# 21

# %%
groups.size()
# Out:
# Retailer country
# Australia         3665
# Austria           3862
# Belgium           3710
# Brazil            3288
# Canada            5923
# China             3652
# Denmark           2358
# Finland           3409
# France            5779
# Germany           5397
# Italy             4018
# Japan             5359
# Korea             3399
# Mexico            3845
# Netherlands       4199
# Singapore         3443
# Spain             3557
# Sweden            2925
# Switzerland       4103
# United Kingdom    5102
# United States     7482
# dtype: int64

# %% [markdown]
# Pierwszy wiersza dla każdej grupy

# %%
groups.first().head()
# Out:
#                  Order method type  Retailer type  ... Quantity Gross margin
# Retailer country                                   ...
# Australia                Telephone      Golf Shop  ...       53     0.509564
# Austria                  Telephone      Golf Shop  ...      137     0.373695
# Belgium                        Web      Golf Shop  ...       57     0.509564
# Brazil                         Web      Golf Shop  ...      219     0.419206
# Canada                         Fax  Outdoors Shop  ...      165     0.418630
#
# [5 rows x 10 columns]

# %%
products[products['Retailer country'] == 'Australia'].head(1)
# Out:
#      Retailer country Order method type  ... Quantity Gross margin
# 3735        Australia         Telephone  ...       53     0.509564
#
# [1 rows x 11 columns]

# %%
products[products['Retailer country'] == 'Brazil'].head(1)
# Out:
#      Retailer country Order method type  ... Quantity Gross margin
# 1833           Brazil               Web  ...      219     0.419206
#
# [1 rows x 11 columns]

# %%
groups.last().head()
# Out:
#                  Order method type     Retailer type  ... Quantity Gross margin
# Retailer country                                      ...
# Australia              Sales visit  Department Store  ...      169     0.511327
# Austria                        Web      Sports Store  ...     2194     0.524254
# Belgium                        Web      Sports Store  ...       93     0.350754
# Brazil                         Web      Sports Store  ...     1505     0.524254
# Canada                         Web      Sports Store  ...     2566     0.524254
#
# [5 rows x 10 columns]

# %%
groups.groups
# Out:
# {'Australia': [3735, 3736, 3737, 3738, 3739, 3740, 3741, 3742, 3743, 3744, 3745, 3746, 3747, 3748, 3749, 3750, 3751, 3752, 3753, 3754, 3755, 3756, 3757, 3758, 3759, 3760, 3761, 3762, 3763, 3764, 3765, 3766, 3767, 3768, 3769, 3770, 3771, 3772, 3773, 3774, 3775, 3776, 3777, 3778, 3779, 3780, 3781, 3782, 3783, 3784, 3785, 3786, 3787, 3788, 3789, 3790, 3791, 3792, 3793, 3794, 3795, 3796, 3797, 3798, 3799, 3800, 3801, 3802, 3803, 3804, 3805, 3806, 3807, 3808, 3809, 3810, 3811, 3812, 3813, 3814, 3815, 3816, 3817, 3818, 3819, 3820, 3821, 3822, 3823, 3824, 3825, 3826, 3827, 3828, 3829, 3830, 3831, 3832, 3833, 3834, ...], 'Austria': [7588, 7589, 7590, 7591, 7592, 7593, 7594, 7595, 7596, 7597, 7598, 7599, 7600, 7601, 7602, 7603, 7604, 7605, 7606, 7607, 7608, 7609, 7610, 7611, 7612, 7613, 7614, 7615, 7616, 7617, 7618, 7619, 7620, 7621, 7622, 7623, 7624, 7625, 7626, 7627, 7628, 7629, 7630, 7631, 7632, 7633, 7634, 7635, 7636, 7637, 7638, 7639, 7640, 7641, 7642, 7643, 7644, 7645, 7646, 7647, 7648,
# ...

# %%
products.loc[groups.groups['Belgium']].head()
# Out:
#      Retailer country Order method type  ... Quantity Gross margin
# 7270          Belgium               Web  ...       57     0.509564
# 7271          Belgium               Web  ...       68     0.496579
# 7272          Belgium               Web  ...       96     0.458979
# 7273          Belgium               Web  ...       87     0.448898
# 7274          Belgium               Web  ...       44     0.571075
#
# [5 rows x 11 columns]

# %%
groups.get_group('Belgium').head()
# Out:
#      Order method type Retailer type  ... Quantity Gross margin
# 7270               Web     Golf Shop  ...       57     0.509564
# 7271               Web     Golf Shop  ...       68     0.496579
# 7272               Web     Golf Shop  ...       96     0.458979
# 7273               Web     Golf Shop  ...       87     0.448898
# 7274               Web     Golf Shop  ...       44     0.571075
#
# [5 rows x 10 columns]
