# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %% [markdown]
# ![2021-08-22 10_40_12-Data Science_ Analiza danych w Python i PANDAS _ Udemy.png](data:image/png;base64,...)

# %%
bar = pd.read_csv('/content/weather_barcelona.csv', index_col='Date')
rom = pd.read_csv('/content/weather_rome.csv', index_col='Date')
ams = pd.read_csv('/content/weather_amsterdam.csv', index_col='Date')

# %%
bar.head()
# Out:
#             TempMax  TempMin  Rain  AvgTempMax  AvgTempMin
# Date
# 2018-01-01       17       11     0          13           7
# 2018-01-02       19        8     0          13           7
# 2018-01-03       23       11     0          13           7
# 2018-01-04       24       15     0          13           7
# 2018-01-05       20       10     0          13           7

# %%
temp_max = pd.DataFrame(index = bar.index)

# %%
temp_max['Barcelona'] = bar['TempMax']
temp_max['Rome'] = rom['TempMax']
temp_max['Amsterdam'] = ams['TempMax']

temp_max.head()
# Out:
#             Barcelona  Rome  Amsterdam
# Date
# 2018-01-01         17    14          8
# 2018-01-02         19    13          9
# 2018-01-03         23    14         11
# 2018-01-04         24    16         11
# 2018-01-05         20    17          8

# %%
temp_max.plot()

# %%
temp_max.plot(figsize=(15,5))

# %%
temp_max.plot(figsize=(10,5), subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fba2ed76e50>,
# ...
#       dtype=object)

# %%
temp_max.plot(figsize=(15,5), title = 'Maksymalna temperatura w miestach')

# %%
temp_max.plot(figsize=(15,5), legend=False)

# %%
temp_max.plot(figsize=(15,5), logy=True)

# %%
temp_max[:10]
# Out:
#             Barcelona  Rome  Amsterdam
# Date
# 2018-01-01         17    14          8
# 2018-01-02         19    13          9
# 2018-01-03         23    14         11
# 2018-01-04         24    16         11
# 2018-01-05         20    17          8
# 2018-01-06         16    17          7
# 2018-01-07         16    19          4
# 2018-01-08         14    20          4
# 2018-01-09         15    16          6
# 2018-01-10         15    14          7

# %%
temp_max[:15].plot(figsize=(15,5), xticks=(range(15)), rot=45)

# %%
temp_max[:7].plot(figsize=(15,5), table=True)
