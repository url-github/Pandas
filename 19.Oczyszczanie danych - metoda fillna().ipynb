# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math

# %% [markdown]
# ![2021-08-15 18_39_08-Window.png](data:image/png;base64,...)

# %%
frame = pd.read_csv('/content/Mcdonalds.csv')
frame.head()
# Out:
#     Category  ... Iron (% Daily Value)
# 0  Breakfast  ...                   15
# 1  Breakfast  ...                    8
# 2  Breakfast  ...                   10
# 3  Breakfast  ...                   15
# 4  Breakfast  ...                   10
#
# [5 rows x 24 columns]

# %% [markdown]
# Zabrudzam dane NaN

# %%
frame.loc[1,'TotalFat']=np.NaN
frame.loc[1,'Saturated Fat']=np.NaN
frame.loc[2,'Saturated Fat']=np.NaN
frame.loc[3,'Category']=np.NaN

# %%
frame.head()
# Out:
#     Category  ... Iron (% Daily Value)
# 0  Breakfast  ...                   15
# 1  Breakfast  ...                    8
# 2  Breakfast  ...                   10
# 3        NaN  ...                   15
# 4  Breakfast  ...                   10
#
# [5 rows x 24 columns]

# %%
frame.fillna(value=0).head()
# Out:
#     Category  ... Iron (% Daily Value)
# 0  Breakfast  ...                   15
# 1  Breakfast  ...                    8
# 2  Breakfast  ...                   10
# 3          0  ...                   15
# 4  Breakfast  ...                   10
#
# [5 rows x 24 columns]

# %%
replaceDefinitionTable = {'Category': 'Unknown', 'TotalFat': 0, 'Saturated Fat': 0}
replaceDefinitionTable
# Out:
# {'Category': 'Unknown', 'Saturated Fat': 0, 'TotalFat': 0}

# %%
frame.fillna(value=replaceDefinitionTable).head()
# Out:
#     Category  ... Iron (% Daily Value)
# 0  Breakfast  ...                   15
# 1  Breakfast  ...                    8
# 2  Breakfast  ...                   10
# 3    Unknown  ...                   15
# 4  Breakfast  ...                   10
#
# [5 rows x 24 columns]

# %% [markdown]
# Punktowo podmieniam dane oraz zapisuje zmianę na pierwotnym Data Frame

# %%
frame['Category'].fillna(value='Unknown', inplace=True)
frame.head()
# Out:
#     Category  ... Iron (% Daily Value)
# 0  Breakfast  ...                   15
# 1  Breakfast  ...                    8
# 2  Breakfast  ...                   10
# 3    Unknown  ...                   15
# 4  Breakfast  ...                   10
#
# [5 rows x 24 columns]

# %%
frame['TotalFat'].fillna(value=0, inplace=True)
frame.head()
# Out:
#     Category  ... Iron (% Daily Value)
# 0  Breakfast  ...                   15
# 1  Breakfast  ...                    8
# 2  Breakfast  ...                   10
# 3    Unknown  ...                   15
# 4  Breakfast  ...                   10
#
# [5 rows x 24 columns]

# %%
frame['Saturated Fat'].fillna(value=0, inplace=True)
frame.head()
# Out:
#     Category  ... Iron (% Daily Value)
# 0  Breakfast  ...                   15
# 1  Breakfast  ...                    8
# 2  Breakfast  ...                   10
# 3    Unknown  ...                   15
# 4  Breakfast  ...                   10
#
# [5 rows x 24 columns]

# %% [markdown]
# Ponownie zabrudzam dane NaN

# %%
frame.loc[1,'TotalFat']=np.NaN
frame.loc[1,'Saturated Fat']=np.NaN
frame.loc[2,'Saturated Fat']=np.NaN
frame.loc[3,'Category']=np.NaN

# %%
frame.head()
# Out:
#     Category  ... Iron (% Daily Value)
# 0  Breakfast  ...                   15
# 1  Breakfast  ...                    8
# 2  Breakfast  ...                   10
# 3        NaN  ...                   15
# 4  Breakfast  ...                   10
#
# [5 rows x 24 columns]

# %% [markdown]
# Dodanie wartości średniej

# %%
avgTotalFat = frame['TotalFat'].mean()
avgTotalFat
# Out:
# 14.18918918918919

# %%
frame['TotalFat'].fillna(avgTotalFat,inplace=True)
frame.head()
# Out:
#     Category  ... Iron (% Daily Value)
# 0  Breakfast  ...                   15
# 1  Breakfast  ...                    8
# 2  Breakfast  ...                   10
# 3        NaN  ...                   15
# 4  Breakfast  ...                   10
#
# [5 rows x 24 columns]

# %% [markdown]
# Zastąpienie NaN wartością z poprzedniego wiersza

# %%
frame['Saturated Fat'].fillna(method='ffill', inplace=True)
frame.head()
# Out:
#     Category  ... Iron (% Daily Value)
# 0  Breakfast  ...                   15
# 1  Breakfast  ...                    8
# 2  Breakfast  ...                   10
# 3        NaN  ...                   15
# 4  Breakfast  ...                   10
#
# [5 rows x 24 columns]
